# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий из HeadHunter

# %%
import pandas as pd
import psycopg2

# %%
DBNAME = 'project_sql'
USER = 'skillfactory'
PASSWORD = 'cCkxxLVrDE8EbvjueeMedPKt'
HOST = '84.201.134.129'
PORT = 5432

# %%
connection = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    host=HOST,
    password=PASSWORD,
    port=PORT
)

# %% [markdown]
# # Юнит 3. Предварительный анализ данных

# %% [markdown]
# 1. Напишите запрос, который посчитает количество вакансий в нашей базе (вакансии находятся в таблице vacancies).

# %%
# текст запроса
query_3_1 = f'''select count(id)
           from vacancies
'''

# %%
df_1 = pd.read_sql_query(query_3_1, connection)
df_1
# Out:
# /tmp/ipython-input-612660153.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_1 = pd.read_sql_query(query_3_1, connection)
#    count
# 0  49197

# %%
query_00 = f'''select *
           from vacancies
'''

# %%
df = pd.read_sql_query(query_00, connection)
df
# Out:
# /tmp/ipython-input-383223488.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query_00, connection)
#              id                                               name  \
# 0      55312386                                Компьютерный Мастер
# 1      55843014                            Системный администратор
# 2      54525964                      Lead Java Developer to Poland
# 3      54525965                      Lead Java Developer to Poland
# 4      55354053  Специалист службы поддержки с техническими зна...
# ...         ...                                                ...
# 49192  55589514           Специалист по информационным технологиям
# 49193  55029668                     Руководитель процессного офиса
# 49194  66172263                         Начальник сервисной службы
# ...

# %% [markdown]
# 2. Напишите запрос, который посчитает количество работодателей (таблица employers).

# %%
query_3_2 = f'''select count(id)
           from employers
'''

# %%
# результат запроса
df_2 = pd.read_sql_query(query_3_2, connection)
df_2
# Out:
# /tmp/ipython-input-2828450268.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_2 = pd.read_sql_query(query_3_2, connection)
#    count
# 0  23501

# %% [markdown]
# 3. Посчитате с помощью запроса количество регионов (таблица areas).

# %%
query_3_3 = f'''select count(id)
           from areas
'''

# %%
df_3 = pd.read_sql_query(query_3_3, connection)
df_3
# Out:
# /tmp/ipython-input-3632363039.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_3 = pd.read_sql_query(query_3_3, connection)
#    count
# 0   1362

# %% [markdown]
# 4. Посчитате с помощью запроса количество сфер деятельности в базе (таблица industries).

# %%
query_3_4 = f'''select count(id)
           from industries
'''

# %%
df_4 = pd.read_sql_query(query_3_4, connection)
df_4
# Out:
# /tmp/ipython-input-1227349054.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_4 = pd.read_sql_query(query_3_4, connection)
#    count
# 0    294

# %% [markdown]
# ***

# %% [markdown]
# # Выводы по предварительному анализу данных
# Предварительный анализ данных показал, что у нас есть 5 взаимосвязанных таблиц, в которых хранятся данные по вакансиям и работодателям. Всего представлено 49197 вакансий от 23501 работодателя. Количество регионов (городов), по которым у нас есть сведения - 1362. Сфер деятельности - 294.

# %% [markdown]
# # Юнит 4. Детальный анализ вакансий

# %% [markdown]
# 1. Напишите запрос, который позволит узнать, сколько (cnt) вакансий в каждом регионе (area).
# Отсортируйте по количеству вакансий в порядке убывания.

# %%
query_3_5 = f'''select a.name,
                      count(v.id)::int count
           from areas a
                join vacancies v on a.id = v.area_id
          group by (a.id)
          order by 2 desc
'''

# %%
df_5 = pd.read_sql_query(query_3_5, connection)
df_5.head(10)
# Out:
# /tmp/ipython-input-1436106457.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5 = pd.read_sql_query(query_3_5, connection)
#               name  count
# 0           Москва   5333
# 1  Санкт-Петербург   2851
# 2            Минск   2112
# 3      Новосибирск   2006
# 4           Алматы   1892
# 5     Екатеринбург   1698
# 6  Нижний Новгород   1670
# 7           Казань   1415
# 8        Краснодар   1301
# 9           Самара   1144

# %%
import matplotlib.pyplot as plt # Импортируем сразу все библиотеки для визуализации
# %matplotlib inline
plt.style.use('default')
import seaborn as sns

# %%
top_cities = df_5.head(10)
fig = plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_cities,
    x="name",
    y="count"
)
plt.xticks(rotation=45)
plt.title('Топ-10 городов по количеству вакансий')
plt.xlabel('')
plt.ylabel('Количество вакансий')
plt.show();

# %% [markdown]
# 2. Напишите запрос, чтобы определить у какого количества вакансий заполнено хотя бы одно из двух полей с зарплатой.

# %%
query_3_6 = f'''select count(id)
           from vacancies
           where salary_from	is not NULL or salary_to is not NULL
'''

# %%
df_6 = pd.read_sql_query(query_3_6, connection)
df_6
# Out:
# /tmp/ipython-input-2572318467.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6 = pd.read_sql_query(query_3_6, connection)
#    count
# 0  24073

# %% [markdown]
# 3. Найдите средние значения для нижней и верхней границы зарплатной вилки. Округлите значения до целого.

# %%
query_3_7 = f'''select round(avg(salary_from), 0) avg_from,
                      round(avg(salary_to), 0) avg_to
           from vacancies
'''

# %%
df_7 = pd.read_sql_query(query_3_7, connection)
df_7
# Out:
# /tmp/ipython-input-399059405.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_7 = pd.read_sql_query(query_3_7, connection)
#    avg_from    avg_to
# 0   71065.0  110537.0

# %% [markdown]
# 4. Напишите запрос, который выведет количество вакансий для каждого сочетания типа рабочего графика (schedule) и типа трудоустройства (employment), используемого в вакансиях. Результат отсортируйте по убыванию количества.

# %%
query_3_8 = f'''select schedule, employment,
                        count(id)
           from vacancies
           group by 1, 2
           order by 3 desc
'''

# %%
df_8 = pd.read_sql_query(query_3_8, connection)
df_8
# Out:
# /tmp/ipython-input-164844701.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_8 = pd.read_sql_query(query_3_8, connection)
#             schedule           employment  count
# 0        Полный день     Полная занятость  35367
# 1   Удаленная работа     Полная занятость   7802
# 2      Гибкий график     Полная занятость   1593
# 3   Удаленная работа  Частичная занятость   1312
# 4     Сменный график     Полная занятость    940
# 5        Полный день           Стажировка    569
# 6     Вахтовый метод     Полная занятость    367
# 7        Полный день  Частичная занятость    347
# 8      Гибкий график  Частичная занятость    312
# 9        Полный день     Проектная работа    141
# 10  Удаленная работа     Проектная работа    133
# 11     Гибкий график           Стажировка    116
# ...

# %% [markdown]
# 5. Напишите запрос, выводящий значения поля Требуемый опыт работы (experience) в порядке возрастания количества вакансий, в которых указан данный вариант опыта.

# %%
query_3_10 = f'''select experience,
                        count(id) count
           from vacancies
           group by 1
           order by 2
'''

# %%
df_3_10 = pd.read_sql_query(query_3_10, connection)
df_3_10
# Out:
# /tmp/ipython-input-230499192.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_3_10 = pd.read_sql_query(query_3_10, connection)
#            experience  count
# 0         Более 6 лет   1337
# 1           Нет опыта   7197
# 2       От 3 до 6 лет  14511
# 3  От 1 года до 3 лет  26152

# %%
ratio_vacancies_experience = df_3_10['count']
sns.set_style("whitegrid")
colors = sns.color_palette('pastel')[0:2]

plt.figure(figsize=(6, 6)) # Задаем размер графика
plt.pie(ratio_vacancies_experience, labels=['Более 6 лет опыта', 'Без опыта', 'Опыт от 1 до 3 лет', 'От 3 до 6 лет опыта'], colors=colors,
        autopct='%1.1f%%', # Отображаем проценты
        wedgeprops={'edgecolor': 'black'}) # Граница сектора

plt.title('Количество вакансий в зависимости от опыта', fontsize=16);

# %% [markdown]
# ***

# %% [markdown]
# # Выводы по анализу вакансий
# Анализ показал, что наибольшее количество вакансий предлагается в Москве, Питере и городах-миллионниках. Также в данных писутствуют столицы соседних Белоруссии (г. Минск) и Казахстана (г. Алматы). Более 70% всех вакансий предполагает полную занятость и работу на полный рабочий день. Необходимо отметить, что вакансий в которых указана хотя бы одна граница зарплатной вилки менее половины от всего количества. Если же рассмотреть вакансии относительно требуемого опыта, то самая большая востребованность специалистов, имеющих от 3 до 6 лет опыта, а вакансий не требующих опыта почти в 3 раза больше, чем вакансий с требуемым опытом более 6 лет.

# %% [markdown]
# # Юнит 5. Анализ работодателей

# %% [markdown]
# 1. Напишите запрос, который позволит узнать, какие работодатели находятся на первом и пятом месте по количеству вакансий.

# %%
query_5_1 = f'''select e.name,
                      count(v.id) count
           from employers e
                join vacancies v on e.id = v.employer_id
          group by 1
          order by 2 desc
'''

# %%
df_5_1 = pd.read_sql_query(query_5_1, connection)
df_5_1.head(5)
# Out:
# /tmp/ipython-input-1978207983.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_1 = pd.read_sql_query(query_5_1, connection)
#             name  count
# 0         Яндекс   1933
# 1     Ростелеком    491
# 2       Тинькофф    444
# 3           СБЕР    428
# 4  Газпром нефть    331

# %%
top_employers = df_5_1.head(10)
fig = plt.figure(figsize=(12, 6))

sns.barplot(
    data=top_employers,
    x="name",
    y="count"
)
plt.xticks(rotation=45)
plt.title('Топ-10 компаний-работодателей по количеству вакансий')
plt.xlabel('')
plt.ylabel('Количество вакансий')
plt.show();

# %% [markdown]
# 2. Напишите запрос, который для каждого региона выведет количество работодателей и вакансий в нём.
# Среди регионов, в которых нет вакансий, найдите тот, в котором наибольшее количество работодателей.

# %%
query_5_2 = f'''select a.name,
                      count(e.id) count_employers,
                      count(v.id) count_vacancies
           from  areas a
                left join vacancies v on a.id = v.area_id
                left join employers e on a.id = e.area
          group by 1
          having count(v.id) = 0
          order by 2 desc
          limit 5
'''

# %%
df_5_2 = pd.read_sql_query(query_5_2, connection)
df_5_2
# Out:
# /tmp/ipython-input-762398461.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_2 = pd.read_sql_query(query_5_2, connection)
#                  name  count_employers  count_vacancies
# 0              Россия              410                0
# 1           Казахстан              207                0
# 2  Московская область               75                0
# 3  Краснодарский край               19                0
# 4            Беларусь               18                0

# %% [markdown]
# 3. Для каждого работодателя посчитайте количество регионов, в которых он публикует свои вакансии. Отсортируйте результат по убыванию количества.

# %%
query_5_3 = f'''select e.name,
                      count(distinct a.id) count_areas
           from  employers e
                join vacancies v on e.id = v.employer_id
                join areas a on a.id = v.area_id
          group by 1
          order by 2 desc
          limit 1
'''

# %%
df_5_3 = pd.read_sql_query(query_5_3, connection)
df_5_3
# Out:
# /tmp/ipython-input-3556584873.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_3 = pd.read_sql_query(query_5_3, connection)
#      name  count_areas
# 0  Яндекс          181

# %% [markdown]
# 4. Напишите запрос для подсчёта количества работодателей, у которых не указана сфера деятельности.

# %%
query_5_4 = f'''select count(e.id) count_empl
                from  employers e
                      left join employers_industries i on e.id = i.employer_id
                where industry_id is NULL
'''

# %%
df_5_4 = pd.read_sql_query(query_5_4, connection)
df_5_4
# Out:
# /tmp/ipython-input-2345892774.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_4 = pd.read_sql_query(query_5_4, connection)
#    count_empl
# 0        8419

# %% [markdown]
# 5. Напишите запрос, чтобы узнать название компании, находящейся на третьем месте в алфавитном списке (по названию) компаний, у которых указано четыре сферы деятельности.

# %%
query_5_5 = f'''select e.name, count(distinct i.industry_id) cnt_industries
                from  employers e
                      join employers_industries i on e.id = i.employer_id
                group by 1
                having count(distinct i.industry_id) = 4
                order by 1
                limit 3
'''

# %%
df_5_5 = pd.read_sql_query(query_5_5, connection)
df_5_5
# Out:
# /tmp/ipython-input-480638788.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_5 = pd.read_sql_query(query_5_5, connection)
#            name  cnt_industries
# 0  101 Интернет               4
# 1      21vek.by               4
# 2          2ГИС               4

# %% [markdown]
# 6. С помощью запроса выясните, у какого количества работодателей в качестве сферы деятельности указана Разработка программного обеспечения.

# %%
query_5_6 = f'''select count(employer_id) cnt_employers
                from  industries i
                      join employers_industries e on i.id = e.industry_id
                where i.name ilike 'Разработка программного обеспечения'
'''

# %%
df_5_6 = pd.read_sql_query(query_5_6, connection)
df_5_6
# Out:
# /tmp/ipython-input-3865320243.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_6 = pd.read_sql_query(query_5_6, connection)
#    cnt_employers
# 0           3553

# %% [markdown]
# 7. Для компании «Яндекс» выведите список регионов-миллионников, в которых представлены вакансии компании, вместе с количеством вакансий в этих регионах. Также добавьте строку Total с общим количеством вакансий компании. Результат отсортируйте по возрастанию количества.
#
# Список городов-милионников надо взять [отсюда](https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D1%80%D0%BE%D0%B4%D0%B0-%D0%BC%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%B5%D1%80%D1%8B_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8).
#
# Если возникнут трудности с этим задание посмотрите материалы модуля  PYTHON-17. Как получать данные из веб-источников и API.

# %%
# С помощью библиотек requests и BeautifulSoup и парсинга указанного сайта получим перечень городов-миллионников
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

url = 'https://ru.wikipedia.org/wiki/Города-миллионеры_России'
response = requests.get(url, headers=headers)
page = BeautifulSoup(response.text, 'html.parser')

table = (page.find('table', class_='wikitable sortable') or
         page.find('table', class_='wikitable') or
         page.find('table'))

million_cities = []
rows = table.find_all('tr')[1:17]  # Первые 17 строк без заголовка

for i, row in enumerate(rows):
    cells = row.find_all(['th', 'td'])

    city_cell = cells[1]
    city_name = city_cell.get_text(strip=True)
    million_cities.append(city_name)

print(f"Города-миллионеры России {million_cities}")
million_cities_str = ', '.join(f"'{city}'" for city in million_cities)
# Out:
# Города-миллионеры России ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань', 'Красноярск', 'Нижний Новгород', 'Челябинск', 'Уфа', 'Краснодар', 'Самара', 'Ростов-на-Дону', 'Омск', 'Воронеж', 'Пермь', 'Волгоград']

# %%
query_5_7 = f'''with yandex_mil_cities as
                (
                  select a.name,
                      count(distinct v.id) cnt
                  from  vacancies v
                      join employers e on e.id = v.employer_id
                      join areas a on a.id = v.area_id
                  where e.name ilike 'яндекс' and a.name in ({million_cities_str})
                  group by 1
                  order by 1
                  ),
                  yandex_total as
                  (
                    select 'Total' as total,
                            sum(cnt) as total_vac
                    from yandex_mil_cities
                    group by 1
                  )

                  select name, cnt from yandex_mil_cities
                  UNION
                  select total, total_vac from yandex_total
                  order by 2, 1
'''

# %%
df_5_7 = pd.read_sql_query(query_5_7, connection)
df_5_7
# Out:
# /tmp/ipython-input-43835236.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_5_7 = pd.read_sql_query(query_5_7, connection)
#                name    cnt
# 0              Омск   21.0
# 1         Челябинск   22.0
# 2        Красноярск   23.0
# 3         Волгоград   24.0
# 4            Казань   25.0
# 5             Пермь   25.0
# 6    Ростов-на-Дону   25.0
# 7            Самара   26.0
# 8               Уфа   26.0
# 9         Краснодар   30.0
# 10          Воронеж   32.0
# 11      Новосибирск   35.0
# 12  Нижний Новгород   36.0
# 13     Екатеринбург   39.0
# 14  Санкт-Петербург   42.0
# 15           Москва   54.0
# 16            Total  485.0

# %% [markdown]
# ***

# %% [markdown]
# # Выводы по анализу работодателей
# Лидером по количеству вакансий является компания Яндекс. Вакансии компании составляют почти 4% от всех вакансий в базе данных. У этой компании опубликовано 1933 вакансии в 181 регоне/городе. В черверти вакансий компании Яндекс предлагается работа в Мескве, Санкт-Перебурге и городах-милионниках. С большим отрывом от Яндекса по количеству вакансий идут комании Ростелеком, Тинькофф, Сбер, Газпромнефть. У них размещено 491, 444, 428 и 331 вакансия соответственно. У 15% работодателей в качестве сферы деятельности указана разработка программного обеспечения. Почти у 36% работодателей сфера деятельности не указана вовсе и в этом случае можно порекомендовать сделать это поле для работодателей обязательным, так как это может помочь соискателям с выбором подходящей вакансии.

# %% [markdown]
# # Юнит 6. Предметный анализ

# %% [markdown]
# 1. Сколько вакансий имеет отношение к данным?
#
# Считаем, что вакансия имеет отношение к данным, если в её названии содержатся слова 'data' или 'данн'.
#
# *Подсказка: Обратите внимание, что названия вакансий могут быть написаны в любом регистре.*

# %%
query_6_1 = f'''select count(id) cnt_vacancies
                from vacancies
                where (name ilike '%data%') or (name ilike '%данн%')
'''

# %%
df_6_1 = pd.read_sql_query(query_6_1, connection)
df_6_1
# Out:
# /tmp/ipython-input-1300834887.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_1 = pd.read_sql_query(query_6_1, connection)
#    cnt_vacancies
# 0           1771

# %% [markdown]
# 2. Сколько есть подходящих вакансий для начинающего дата-сайентиста?
# Будем считать вакансиями для дата-сайентистов такие, в названии которых есть хотя бы одно из следующих сочетаний:
# * 'data scientist'
# * 'data science'
# * 'исследователь данных'
# * 'ML' (здесь не нужно брать вакансии по HTML)
# * 'machine learning'
# * 'машинн%обучен%'
#
# ** В следующих заданиях мы продолжим работать с вакансиями по этому условию.*
#
# Считаем вакансиями для специалистов уровня Junior следующие:
# * в названии есть слово 'junior' *или*
# * требуемый опыт — Нет опыта *или*
# * тип трудоустройства — Стажировка.

# %%
query_6_2 = f'''SELECT count(id) cnt_vacancies
                FROM vacancies
                WHERE
                   (name ILIKE '%data scientist%' OR
                    name ILIKE '%data science%' OR
                    name ILIKE '%исследователь данных%' OR
                    name ILIKE '%machine learning%' OR
                    name ILIKE '%машинн%обучен%' OR
                    name ILIKE '%ML%')
                    AND name NOT ILIKE '%html%'
                    AND
                     (name ILIKE '%junior%' OR
                      experience ILIKE '%нет опыта%' OR
                      employment ILIKE '%стажировка%')
  '''

# %%
df_6_2 = pd.read_sql_query(query_6_2, connection)
df_6_2
# Out:
# /tmp/ipython-input-2048769617.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_2 = pd.read_sql_query(query_6_2, connection)
#    cnt_vacancies
# 0             51

# %% [markdown]
# 3. Сколько есть вакансий для DS, в которых в качестве ключевого навыка указан SQL или postgres?
#
# ** Критерии для отнесения вакансии к DS указаны в предыдущем задании.*

# %%
query_6_3 = f'''SELECT count(id) cnt_vacancies
                FROM vacancies
                WHERE
                   (name ILIKE '%data scientist%' OR
                    name ILIKE '%data science%' OR
                    name ILIKE '%исследователь данных%' OR
                    name ILIKE '%machine learning%' OR
                    name ILIKE '%машинн%обучен%' OR
                    name ILIKE '%ML%')
                    AND name NOT ILIKE '%html%'
                    AND
                    (key_skills ILIKE '%sql%' OR
                    key_skills ILIKE '%postgres%')
'''

# %%
df_6_3 = pd.read_sql_query(query_6_3, connection)
df_6_3
# Out:
# /tmp/ipython-input-3192746363.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_3 = pd.read_sql_query(query_6_3, connection)
#    cnt_vacancies
# 0            229

# %% [markdown]
# 4. Проверьте, насколько популярен Python в требованиях работодателей к DS.Для этого вычислите количество вакансий, в которых в качестве ключевого навыка указан Python.
#
# ** Это можно сделать помощью запроса, аналогичного предыдущему.*

# %%
query_6_4 = f'''SELECT count(id) cnt_vacancies
                FROM vacancies
                WHERE
                   (name ILIKE '%data scientist%' OR
                    name ILIKE '%data science%' OR
                    name ILIKE '%исследователь данных%' OR
                    name ILIKE '%machine learning%' OR
                    name ILIKE '%машинн%обучен%' OR
                    name ILIKE '%ML%')
                    AND name NOT ILIKE '%html%'
                    AND
                    (key_skills ILIKE '%Python%')
'''

# %%
df_6_4 = pd.read_sql_query(query_6_4, connection)
df_6_4
# Out:
# /tmp/ipython-input-1319374162.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_4 = pd.read_sql_query(query_6_4, connection)
#    cnt_vacancies
# 0            357

# %% [markdown]
# 5. Сколько ключевых навыков в среднем указывают в вакансиях для DS?
# Ответ округлите до двух знаков после точки-разделителя.

# %%
query_6_5 = f'''SELECT
    ROUND(AVG(CHAR_LENGTH(key_skills) - CHAR_LENGTH(replace(key_skills, CHR(9), '')) + 1), 2) AS "Количество Слов"

    FROM vacancies
    WHERE
        (lower(name) LIKE '%data scientist%' OR
        lower(name) LIKE '%data science%' OR
        lower(name) LIKE '%исследователь данных%' OR
        (name LIKE '%ML%' AND lower(name) NOT LIKE'%html%') OR
        lower(name) LIKE '%machine learning%' OR
        lower(name) LIKE '%машинн%обучен%') AND
        (key_skills IS NOT NULL AND key_skills != '')

'''

# %%
df_6_5 = pd.read_sql_query(query_6_5, connection)
df_6_5.head(20)
# Out:
# /tmp/ipython-input-1987122180.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_5 = pd.read_sql_query(query_6_5, connection)
#    Количество Слов
# 0             6.41

# %%
connection.close()

# %% [markdown]
# 6. Напишите запрос, позволяющий вычислить, какую зарплату для DS в **среднем** указывают для каждого типа требуемого опыта (уникальное значение из поля *experience*).
#
# При решении задачи примите во внимание следующее:
# 1. Рассматриваем только вакансии, у которых заполнено хотя бы одно из двух полей с зарплатой.
# 2. Если заполнены оба поля с зарплатой, то считаем зарплату по каждой вакансии как сумму двух полей, делённую на 2. Если заполнено только одно из полей, то его и считаем зарплатой по вакансии.
# 3. Если в расчётах участвует null, в результате он тоже даст null (посмотрите, что возвращает запрос select 1 + null). Чтобы избежать этой ситуацию, мы воспользуемся функцией [coalesce](https://postgrespro.ru/docs/postgresql/9.5/functions-conditional#functions-coalesce-nvl-ifnull), которая заменит null на значение, которое мы передадим. Например, посмотрите, что возвращает запрос `select 1 + coalesce(null, 0)`
#
# Выясните, на какую зарплату в среднем может рассчитывать дата-сайентист с опытом работы от 3 до 6 лет. Результат округлите до целого числа.

# %%
query_6_7 = f'''With ds_salaries as
                (
                  select id, experience,
                         coalesce(salary_from, 0) salary_from,
                         coalesce(salary_to, 0) salary_to
                from vacancies
                WHERE
                   (lower(name) LIKE '%data scientist%' OR
                    lower(name) LIKE '%data science%' OR
                    lower(name) LIKE '%исследователь данных%' OR
                    (name LIKE '%ML%' AND lower(name) NOT LIKE'%html%') OR
                    lower(name) LIKE '%machine learning%' OR
                    lower(name) LIKE '%машинн%обучен%')
                    AND (salary_from is not NULL or salary_to is not NULL)
                  )
                select experience,
                       round(avg(
                             case when salary_from = 0 then salary_to
                                  when salary_to = 0 then salary_from
                                  else (salary_from + salary_to)/2.0
                                  end
                                  ), 0) as avg_salary
                  from ds_salaries
                  group by 1
'''

# %%
df_6_7 = pd.read_sql_query(query_6_7, connection)
df_6_7
# Out:
# /tmp/ipython-input-978001746.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_7 = pd.read_sql_query(query_6_7, connection)
#            experience  avg_salary
# 0       От 3 до 6 лет    243115.0
# 1  От 1 года до 3 лет    139675.0
# 2           Нет опыта     74643.0

# %% [markdown]
# # Выводы по предметному анализу
# Более детальный анализ показал, что 1771 вакансия имеет отношение к работе с данными. Для начинающих специалистов в сфере дата сайенс размещена 51 вакансия. Требования знания SQL или Postgres встречабтся в 229 вакансиях, а знания Python указаны в ключевых навыках 357 вакансий. Средняя зарплата специалистов DS варьируется от 75 тыс руб (для специалистов без опыта) до 243 тыс руб (для специалистов имеющих от 3 до 6 лет опыта).

# %% [markdown]
# # Общий вывод по проекту

# %% [markdown]
# 7. Анализ количества вакансий в DS в зависимости от опыта

# %%
query_6_7 = f'''select distinct experience, count(id)
                from vacancies
                WHERE
                   (name ILIKE '%data scientist%' OR
                    name ILIKE '%data science%' OR
                    name ILIKE '%исследователь данных%' OR
                    name ILIKE '%machine learning%' OR
                    name ILIKE '%машинн%обучен%' OR
                    name ILIKE '%ML%')
                    AND name NOT ILIKE '%html%'
                group by 1
'''

# %%
df_6_7 = pd.read_sql_query(query_6_7, connection)
df_6_7
# Out:
# /tmp/ipython-input-978001746.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_7 = pd.read_sql_query(query_6_7, connection)
#            experience  count
# 0         Более 6 лет     43
# 1           Нет опыта     28
# 2  От 1 года до 3 лет    237
# 3       От 3 до 6 лет    228

# %%
ratio_vacancies_experience = df_6_7['count']
sns.set_style("whitegrid")
colors = sns.color_palette('pastel')[0:4]

plt.figure(figsize=(6, 6)) # Задаем размер графика
plt.pie(ratio_vacancies_experience, labels=['Более 6 лет опыта', 'Без опыта', 'Опыт от 1 до 3 лет', 'От 3 до 6 лет опыта'],
        colors=colors, autopct =lambda pct: f'{int(round(pct*sum(ratio_vacancies_experience)/100))}', # на секторах графика будут указано количество вакансий
        wedgeprops={'edgecolor': 'black'}) # Граница сектора

plt.title('Количество вакансий DS в зависимости от опыта', fontsize=16);

# %% [markdown]
# ***

# %% [markdown]
# Как видно из графика больше всего вакансий для специалистов имеющих от 1 до 3 лет и от 3 до 6 лет опыта. В этих категориях количество вакансий различается незначительно. При этом вакансий для сотрудников имеющих более 6 лет опыта всего на 15 вакансий больше, чем для сотрудников без опыта.

# %% [markdown]
# 8. Выведем перечень компаний предлагающих вакансии для специалистов DS с разбивкой по уровню опыт

# %%
query_6_8 = f'''select distinct e.name, experience, count(v.id)
                from vacancies v
                     join employers e on v.employer_id = e.id
                WHERE
                   (v.name ILIKE '%data scientist%' OR
                    v.name ILIKE '%data science%' OR
                    v.name ILIKE '%исследователь данных%' OR
                    v.name ILIKE '%machine learning%' OR
                   v.name ILIKE '%машинн%обучен%' OR
                    v.name ILIKE '%ML%')
                    AND v.name NOT ILIKE '%html%'
                group by 1, 2
                order by 3 desc
                limit 10
'''

# %%
df_6_8 = pd.read_sql_query(query_6_8, connection)
df_6_8
# Out:
# /tmp/ipython-input-2743337041.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_8 = pd.read_sql_query(query_6_8, connection)
#                     name          experience  count
# 0        Bell Integrator         Более 6 лет     25
# 1                   СБЕР       От 3 до 6 лет     21
# 2         Банк ВТБ (ПАО)  От 1 года до 3 лет     17
# 3                   СБЕР  От 1 года до 3 лет     17
# 4  Positive Technologies       От 3 до 6 лет     11
# 5         EvenBet Gaming       От 3 до 6 лет      9
# 6                     VK  От 1 года до 3 лет      9
# 7               Andersen       От 3 до 6 лет      7
# 8     Бэнкс Софт Системс  От 1 года до 3 лет      6
# 9                 Контур       От 3 до 6 лет      6

# %% [markdown]
# Согласно проведенного анализа видно, что большую часть вакансий размещают банки и интеграторы, которые ищут специалистов с опытом от 1 года и более.

# %% [markdown]
# 9. Дополнительно посмотрим в каких регионах компании предлагают работу начинающим специалистам DS

# %%
query_6_9 = f'''select distinct e.name, a.name, count(v.id)
                from vacancies v
                     join employers e on v.employer_id = e.id
                     join areas a on v.area_id = a.id
                WHERE
                   (v.name ILIKE '%data scientist%' OR
                    v.name ILIKE '%data science%' OR
                    v.name ILIKE '%исследователь данных%' OR
                    v.name ILIKE '%machine learning%' OR
                   v.name ILIKE '%машинн%обучен%' OR
                    v.name ILIKE '%ML%')
                    AND v.name NOT ILIKE '%html%'
                    AND v.experience ILIKE 'Нет опыта'
                group by 1, 2
                order by 3 desc
'''

# %%
df_6_9 = pd.read_sql_query(query_6_9, connection)
df_6_9
# Out:
# /tmp/ipython-input-508110506.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_6_9 = pd.read_sql_query(query_6_9, connection)
#                                                  name             name  count
# 0    The Skolkovo Institute of Science and Technology           Москва      2
# 1                                              Comexp      Новосибирск      1
# 2                                              Comexp  Санкт-Петербург      1
# 3                                              Comexp            Томск      1
# 4                                                DINS  Санкт-Петербург      1
# 5                                   DNS Головной офис      Владивосток      1
# 6                                                Ozon           Москва      1
# ...

# %% [markdown]
# Как видно из таблицы выше, для начинающих специалистов почти все вакансии предлагаются в Москве, Санкт-Перербурге и городах-миллионниках.

# %% [markdown]
# 10. Дополнительно проверим в скольких вакансиях не указана ни верхняя, ни нижняя граница заработной платы.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49197 entries, 0 to 49196
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           49197 non-null  int64
#  1   name         49197 non-null  object
#  2   key_skills   40741 non-null  object
#  3   schedule     49197 non-null  object
#  4   experience   49197 non-null  object
#  5   employment   49197 non-null  object
#  6   salary_from  21485 non-null  float64
#  7   salary_to    12690 non-null  float64
#  8   area_id      49197 non-null  int64
#  9   employer_id  49197 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.8+ MB

# %%
query_7_1 = f'''select count(id)
                from vacancies
                WHERE
                   (salary_from is NULL or salary_from=0) and
                   (salary_to is NULL or salary_to=0)
'''

# %%
df_7_1 = pd.read_sql_query(query_7_1, connection)
df_7_1
# Out:
# /tmp/ipython-input-3921586033.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_7_1 = pd.read_sql_query(query_7_1, connection)
#    count
# 0  25124

# %% [markdown]
# Согласно выполненного анализа более, чем в половине всех вакансий не указан уровень зарплаты, которую готов предложить работодатель.

# %% [markdown]
# # Итоговые выводы
# В качестве подведения итогов следут отметить, что ходе анализа выявлено несколько узких мест, для закрытия которых можно сформулировать несколько рекомендаций. 1. Указание сферы деятельности компании сделать обязательным полем для работодателей. 2. Сделать обязательным заполнение зарплатной вилки (нижней, верхней, либо обеих границ по усмотрению работодателя). Эта информация позволит повысить информированность соискателей, облегчит выбор подходящей вакансии, а также позволит создать рекомендательную систему по поиску вакансий.

# %%
connection.close()
